# %% [markdown]
# # Learning Unit 2

# %% [markdown]
# ## Reading Part - In-Action Ethics

# %% [markdown]
# Please read the abstract and sections 4.1 & 4.2 of the following article:
#
# https://academic.oup.com/iwc/article/29/2/220/2607838
#
# These parts of the article are enough to answer the assignment's questions. You are happily invited to read more parts of the article for more context.

# %% [markdown]
# **Task 1**: The article gives a rigorous definiton of what they call *ethos*. Try to ignore this definition and formulate in 2-3 sentences in your own words what you understand by “ethos” after reading the article.

# %% [markdown]
# Answer: Based on the article, I found that ethos is like a moral backbone of a project or a person but not a rulebook you follow, however something closer to an inner compass that quietly shapes how you to make decisions. It is a kind of thing that develops over time through shared experiences and ongoing conversations within a team. Overall, it is less about what you are supposed to do and more about what you genuinely believe is right and how that belief evolves as your work grows.

# %% [markdown]
# **Task 2**: From your understanding of *ethos*, please describe in 2-3 sentences a project you were part of or you can think of having a *project ethos*.

# %% [markdown]
# Answer: During my last studies, I worked as a student ambassador where we organized open days for prospective students and their families. Looking back, I think our team had a natural shared ethos - we all just genuinely cared about giving people a good first impression of the university, without anyone really having to say it out loud. Nobody needed to be told to help a lost parent or reassure a nervous prospective student, we just did it because that's the kind of team we were.

# %% [markdown]
# ---

# %% [markdown]
# ## Programming Part - Streamlit introduction

# %% [markdown]
# The goal of the programming part is to get you familiar with **streamlit**, a popular python-based open-source framework for data apps, as we will use streamlit at the end of the lecture for the group projects.

# %% [markdown]
# ### Setup & Basic Concepts

# %% [markdown]
# If you are not familiar with streamlit, please work though the main concepts of streamlit: https://docs.streamlit.io/get-started/fundamentals/ following these steps:
#
# 1. Create a local streamlit script `streamlit_tutorial.py`
# 2. Start a local streamlit application with this script
# 3. Then read the concepts and try them in your local script via copy & paste. You should see all visualizations in your browser.
#
# At the end of this tutorial you should have understood how streamlit re-renders, have a feeling on how to display data and which basic visual features exist.
#
# No submission is needed for this part.

# %% [markdown]
# ### Load & Visualize German Credit Data Set

# %% [markdown]
# Now it's your turn! Your task is to build a small interactive web app using **Streamlit** to explore and visualize the **German Credit Data**. The following parts of the app with their tasks are intended to be sections below each other in your steamlit application. You can use `st.subheader` and `st.markdown` to seperate parts visually and add descriptions.
#
#
# #### 📁 Setup Instructions
# - Make sure you have streamlit and pandas installed
# - Place the provided German Credit Data CSV file named `german_credit_data_processed.csv` in the **same folder** as your streamlit python script.
# - Only use **Streamlit and Pandas** (no other libraries)
#
# #### ✅ Part 1: Load the Data
# - Load `german_credit_data_processed.csv` using pandas.
# - Use `@st.cache_data` so that the file is **only loaded once**.
# - Show a success message with `st.success`
#
#
# #### ✅ Part 2: Show a Preview
# - Display the first few rows of the dataset
# - Add a **multiselect widget** to choose columns to display with `st.multiselect`
#
#
# #### ✅ Part 3: Add Bar Chart for Value Counts
# - Let the user select any column with st.selectbox
# - If it’s categorical or has < 20 unique values, show a bar chart with `st.bar_chart`
# - Else show a warning with `st.warning`
#
#
# #### ✅ Part 4: Add Line Chart for Numerical Columns
# - Let the user choose numeric columns for a line chart with `st.multiselect` & `st.line_chart`
#
#
# #### ✅ Part 5: Show a Correlation Table
# - Show correlation matrix of numeric columns with `st.dataframe` & pandas correlation matrix
#
#
# ##### 📸 Bonus (Optional)
#
# If you feel like keep going, you can add one or more of the following features:
# - A sidebar (`st.sidebar`) for controls
# - A text input to filter rows
# - A collapsible statistics section using `st.expander()` and `df.describe()`
#
#
# ---

# %% [markdown]
# ### Submission
#
# Please copy the complete content of your final streamlit `.py` file below this cell

# %%
import streamlit as st
import pandas as pd

# Part 1

st.title("German Credit Data Explorer")

@st.cache_data
def load_data():
    df = pd.read_csv("german_credit_data_processed.csv")
    return df

df = load_data()

# Part 2

st.subheader("Data Preview")

all_columns = df.columns.tolist()
selected_columns = st.multiselect("Choose columns to display", all_columns, default=all_columns)

if selected_columns:
    st.dataframe(df[selected_columns].head())
else:
    st.warning("Please select at least one column.")

# Part 3

st.subheader("Bar Chart")

selected_col = st.selectbox("Choose a column", df.columns.tolist())

if df[selected_col].nunique() < 20:
    value_counts = df[selected_col].value_counts()
    st.bar_chart(value_counts)
else:
    st.warning("Too many values to display as a bar chart.")

# Part 4

st.subheader("Line Chart")

numeric_columns = df.select_dtypes(include='number').columns.tolist()
selected_numeric = st.multiselect("Choose numeric columns", numeric_columns, default=numeric_columns[:1])

if selected_numeric:
    st.line_chart(df[selected_numeric])
else:
    st.warning("Please select at least one numeric column.")

# Part 5

st.subheader("Correlation Table")

numeric_df = df.select_dtypes(include='number')
st.dataframe(numeric_df.corr())

# Bonus

st.sidebar.title("Controls")
st.sidebar.markdown("Use the widgets below to explore the data.")

with st.expander("Show Statistics"):
    st.dataframe(df.describe())

# %% [markdown]
# # 📝 Feedback
# We are interested in your feedback in order to improve this course. We will read all of your feedback and evaluate it. What you share may have a direct impact on the rest of the course or future iterations of it.
#
# Write down your feedback on the lecture, the exercises, or the assignments in the Markdown cell below. Furthermore, please note the approximate time it took you to complete the assignment. You may also write about your insights, what you found interesting, or questions that you have.
