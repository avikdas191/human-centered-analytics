# %% [markdown]
# # Group Project VI — Iterate with User Feedback, Documentation & Presentation

# %% [markdown]
# You have made it to the final assignment of the group project. Congratulations! For this assignment, you will finish developing your explanation interface and prepare all deliverables for submission.

# %% [markdown]
# **✏️ Task 1** — **User Study Feedback**
# In the last exercise, you conducted a study with test users and documented their feedback.
# 1. *Summarize the feedback you received in the user study from the last exercise session. Highlight the key points that were mentioned.*
# 2. *Discuss design implications you drew from this feedback within the group and write them down.*
# 3. *State the changes you want to implement based on the design implications.*
#
# *Write down your answers in the README section of your repository under a heading **User Study Feedback***

# %% [markdown]
# **✏️ Task 2** — **Iterate and finalize your prototype implementation**
# *Work on your explanation interface application with the received feedback and implement any remaining changes.*
#
# Push your code to the repository. Your application must be runnable. Check also the best practices on reproducible environments from assignment number 3.

# %% [markdown]
# **✏️ Task 3** — **Project Description**
# *Create a project description document (approximately 1000 words) that includes descriptions of:*
# - *your project goals*
# - *your intended target audience*
# - *your dataset and its documentation*
# - *key design decisions you made (describe taken decisions from first ideas over low-fidelity paper-prototypes to high-fidelity prototypes until iteration with feedback from the user interviews)*
# - *the problems you faced*
# - *your reflections on the development process*
#
# *Export your document as a PDF (check Task 6 for submission format).*

# %% [markdown]
# **✏️ Task 4** — **Presentation**
# Prepare slides for your presentation on July 16, 2026.
#
# *Make sure that your presentation covers the following points:*
# - *Present your project description information in a comprehensive manner.*
# - *Clearly outline the main questions you aimed to answer with your explanation interface.*
# - *Present the key design choices you made during the project.*
# - *Engage the audience by providing a live demonstration of your explanation interface.*
# - **Important:** *Examine and discuss how the received user feedback from the interviews influenced and shaped your final design.*
#
# *Keep these details in mind as you prepare your presentation:*
# - *The presentation has a strict time limit of 10 minutes.*
# - *Following the presentation, there will be a 10-minute discussion round.*
# - *All deliverables need to be submitted before the presentation.*
# - *Determine in advance which team member(s) will be delivering the presentation.*
# - *To keep the schedule on track, be on time for the presentation!*
#
# *Export your presentation as a PDF (check Task 6 for submission format).*

# %% [markdown]
# **✏️ Task 5** — **Screencast**
# *Prepare a screencast of your explanation interface application. The video should be approximately 90 seconds long, narrated, and it should show the main interactions of your application.*
#
# *Export your screen in a common video format (e.g., MP4).*

# %% [markdown]
# **✏️ Task 6** — **Submission to Whiteboard:**
# *Finally, submit all your deliverables to Whiteboard (in ZIP format) and your repository.*
#
# *The required deliverables from each task are:*
# - *Your User Study Feedback and Design Implications pushed to the README of your repository.*
# - *Your runnable explanation interface application (e.g., Python scripts, dataset, documentation) pushed to your repository.*
# - *Your project description as a PDF* (Upload to Whiteboard)
# - *Your project presentation slides as a PDF* (Upload to Whiteboard)
# - *Your screencast in a common video format (e.g., MP4). (Upload to Whiteboard. In case the file size is too large, please upload it to a file sharing site such as Box.FU and provide the link in the project description.)*
